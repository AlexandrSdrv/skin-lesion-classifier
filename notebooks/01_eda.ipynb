# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../data/HAM10000_metadata.csv')

print("Shape:", df.shape)
print("\nColumns:", df.columns.tolist())
df.head()
# Out:
# Shape: (10015, 7)
#
# Columns: ['lesion_id', 'image_id', 'dx', 'dx_type', 'age', 'sex', 'localization']
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
print("Class distribution:")
print(df['dx'].value_counts())

plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='dx', order=df['dx'].value_counts().index)
plt.title('Class Distribution')
plt.xlabel('Lesion Type')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# Class distribution:
# dx
# nv       6705
# mel      1113
# bkl      1099
# bcc       514
# akiec     327
# vasc      142
# df        115
# Name: count, dtype: int64

# %%
print("Missing values:")
print(df.isnull().sum())
# Out:
# Missing values:
# lesion_id        0
# image_id         0
# dx               0
# dx_type          0
# age             57
# sex              0
# localization     0
# dtype: int64

# %%
plt.figure(figsize=(12, 5))
sns.boxplot(data=df, x='dx', y='age', order=df['dx'].value_counts().index)
plt.title('Age Distribution by Lesion Type')
plt.xlabel('Lesion Type')
plt.ylabel('Age')
plt.tight_layout()
plt.show()

print("\nAverage age by lesion type:")
print(df.groupby('dx')['age'].mean().round(1))
# Out:
# Average age by lesion type:
# dx
# akiec    66.5
# bcc      66.8
# bkl      64.3
# df       53.0
# mel      60.7
# nv       46.5
# vasc     51.4
# Name: age, dtype: float64
